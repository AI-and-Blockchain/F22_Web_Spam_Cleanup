# %%
import requests
import json
inp = json.load(open('testInput.json'))
r= requests.post(
    'http://127.0.0.1:5000/verify',
    json = inp,
)

r.status_code
# Out:
# 200

# %%
import pandas as pd
from pathlib import Path

# all_features = pd.read_csv('../ISCXURL2016/All.csv')
# def_features = pd.read_csv('../ISCXURL2016/Defacement.csv')
# mal_features = pd.read_csv('../ISCXURL2016/Malware.csv')
# phi_features = pd.read_csv('../ISCXURL2016/Phishing.csv')
# spa_features = pd.read_csv('../ISCXURL2016/Spam.csv')
# url = pd.read_csv('../ISCXURL2016/URL/Benign_list_big_final.csv')


def parse_df(file,i):
    df = pd.read_csv(file,header=None)
    df[1] = i
    df.columns = ['url','label']
    return df

'''
[PosixPath('../ISCXURL2016/URL/Benign_list_big_final.csv'),
 PosixPath('../ISCXURL2016/URL/DefacementSitesURLFiltered.csv'),
 PosixPath('../ISCXURL2016/URL/Malware_dataset.csv'),
 PosixPath('../ISCXURL2016/URL/phishing_dataset.csv'),
 PosixPath('../ISCXURL2016/URL/spam_dataset.csv')]
'''

urls = pd.concat([
    parse_df(f,i)
     for i,f in enumerate(sorted(Path('../ISCXURL2016/URL/').glob('*.csv')))
])





# ben_url = pd.read_csv('../ISCXURL2016/URL/Benign_list_big_final.csv',header=None)
# def_url = pd.read_csv('../ISCXURL2016/URL/DefacementSitesURLFiltered.csv',header=None)
# mal_url = pd.read_csv('../ISCXURL2016/URL/Malware_dataset.csv',header=None)
# phi_url = pd.read_csv('../ISCXURL2016/URL/phishing_dataset.csv',header=None)
# spa_url = pd.read_csv('../ISCXURL2016/URL/spam_dataset.csv',header=None)


# df.columns
# len(df) == len(pd.read_csv('../ISCXURL2016/URL/Benign_list_big_final.csv'))

# %%
urls.to_csv('url_and_label.csv',index=False)

# %%
ben_url[1] = 0

ben_url
# Out:
#                                                        0  1
# 0      http://1337x.to/torrent/1048648/American-Snipe...  0
# 1      http://1337x.to/torrent/1110018/Blackhat-2015-...  0
# 2      http://1337x.to/torrent/1122940/Blackhat-2015-...  0
# 3      http://1337x.to/torrent/1124395/Fast-and-Furio...  0
# 4      http://1337x.to/torrent/1145504/Avengers-Age-o...  0
# ...                                                  ... ..
# 35373  https://lastpass.com/signup2.php?ac=1&from_uri...  0
# 35374  https://lastpass.com/signup2.php?ac=1&from_uri...  0
# 35375  https://lastpass.com/signup2.php?ac=1&from_uri...  0
# 35376  https://lastpass.com/signup2.php?ac=1&from_uri...  0
# 35377  https://asana.com/guide/videos/%22//fast.wisti...  0
#
# [35378 rows x 2 columns]

# %%
spa_features
# Out:
#        Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0                0                   2                12           5.500000
# 1                0                   3                12           5.000000
# 2                2                   2                11           4.000000
# 3                0                   2                 7           4.500000
# 4               19                   2                10           6.000000
# ...            ...                 ...               ...                ...
# 14474           29                   4                14           5.750000
# 14475            0                   4                13           3.750000
# 14476           58                   3                27           6.666666
# 14477           35                   3                13           4.333334
# 14478           40                   3                25           6.666666
#
# ...

# %%
[c for c in all_features[:4].columns if all_features[:4][c].unique().shape[0] > 3]
# Out:
# ['avgpathtokenlen',
#  'charcompace',
#  'urlLen',
#  'pathLength',
#  'subDirLen',
#  'pathurlRatio',
#  'ArgUrlRatio',
#  'domainUrlRatio',
#  'pathDomainRatio',
#  'argPathRatio',
#  'URL_Letter_Count',
#  'Extension_LetterCount',
#  'Entropy_URL',
#  'Entropy_Filename']

# %%
ben_url
# Out:
#                                                        0
# 0      http://1337x.to/torrent/1048648/American-Snipe...
# 1      http://1337x.to/torrent/1110018/Blackhat-2015-...
# 2      http://1337x.to/torrent/1122940/Blackhat-2015-...
# 3      http://1337x.to/torrent/1124395/Fast-and-Furio...
# 4      http://1337x.to/torrent/1145504/Avengers-Age-o...
# ...                                                  ...
# 35373  https://lastpass.com/signup2.php?ac=1&from_uri...
# 35374  https://lastpass.com/signup2.php?ac=1&from_uri...
# 35375  https://lastpass.com/signup2.php?ac=1&from_uri...
# 35376  https://lastpass.com/signup2.php?ac=1&from_uri...
# 35377  https://asana.com/guide/videos/%22//fast.wisti...
#
# [35378 rows x 1 columns]
